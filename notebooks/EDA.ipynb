# %%
import pandas as pd
import numpy as np
import re 
import sys

sys.path.append( r'C:\personal projects\Email_classifier')

# %%
from src.utils.dataset_loader import  uncleaned

uncleaned.shape
print(uncleaned.dtypes)
print(uncleaned.head(25))

# %%
#look for nulls
uncleaned.info() #character tri grams have null values datatype : str

print((uncleaned.isnull().sum()>0).any())
print(uncleaned[uncleaned.isnull().any(axis=1)])

# %%
# Out:
# Email Address          0.00000
# Category               0.00000
# Subcategory            0.00000
# Local Part             0.00000
# Domain                 0.00000
# Length                 0.00000
# Character Bi-grams     0.00000
# Character Tri-grams    0.01715
# Email Content          0.00000
# Timestamp              0.00000
# Disposable             0.00000
# Spam                   0.00000
# Country                0.00000
# Language               0.00000
# dtype: float64
